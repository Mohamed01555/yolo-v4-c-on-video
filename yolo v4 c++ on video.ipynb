# %%
# clone darknet repo
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 13939, done.
# remote: Total 13939 (delta 0), reused 0 (delta 0), pack-reused 13939
# Receiving objects: 100% (13939/13939), 12.55 MiB | 6.60 MiB/s, done.
# Resolving deltas: 100% (9503/9503), done.

# %%
# change makefile to have GPU and OPENCV enabled
# %cd /content/darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/' Makefile
# Out:
# /content/darknet

# %%
# make darknet (builds darknet so that you can then use the darknet executable file to run or train object detectors)
# !make

# %%
# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.weights

# %%
# %cd ..
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# cd back into the darknet folder to run detections
# %cd darknet

# %%
# This didn't work
# !./darknet detector demo cfg/coco.data cfg/yolov4.cfg yolov4.weights -dont_show /content/gdrive/My Drive/h.mp4 -i 0 -out_filename /content/gdrive/My Drive/results.mp4

# %%
# Also this didn't work
# !./darknet detector demo cfg/coco.data cfg/yolov4.cfg yolov4.weights /content/gdrive/My Drive/h.mp4 -dont_show -i 0 -out_filename /content/gdrive/My Drive/results.avi

# %%
def upload():
  from google.colab import files
  uploaded = files.upload() 
  for name, data in uploaded.items():
    with open(name, 'wb') as f:
      f.write(data)
      print ('saved file', name)

# use this to download a file  
def download(path):
  from google.colab import files
  files.download(path)

# %%
upload()
# Out:
#      <input type="file" id="files-ab0103da-9561-4f29-abcc-5f998857acfe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ab0103da-9561-4f29-abcc-5f998857acfe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Driving Downtown - Berlin 4K - Germany.mp4 to Driving Downtown - Berlin 4K - Germany.mp4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-5b1249ff8ad0> in <module>()
# ----> 1 upload()
#
# <ipython-input-17-4b01f408d7d7> in upload()
#       1 def upload():
#       2   from google.colab import files
# ----> 3   uploaded = files.upload()
#       4   for name, data in uploaded.items():
# ...

# %%
! pip install pytube3

# %%
# %cd /content
# Out:
# /content

# %%
import pytube
link = "https://www.youtube.com/watch?v=1wy3j0FG4So"
yt = pytube.YouTube(link)
stream = yt.streams.first()
stream.download()
# Out:
# '/content/Driving Downtown - Berlin 4K - Germany.mp4'

# %%
# %cd /content/darknet
# Out:
# /content/darknet

# %%
# !./darknet detector demo cfg/coco.data cfg/yolov4.cfg yolov4.weights -dont_show /content/h.mp4 -i 0 -out_filename /content/results.avi
# Out:
# Streaming output truncated to the last 5000 lines.
# truck: 35%
# car: 79%
# truck: 29%
# car: 100%
# car: 87%
# car: 81%
# car: 32%
# car: 26%
# person: 46%
#
# FPS:28.6 	 AVG_FPS:27.4
#
#  cvWriteFrame
# Objects:
#
# truck: 34%
# car: 79%
# car: 100%
# car: 96%
# car: 89%
# car: 32%
# car: 29%
#
# FPS:28.7 	 AVG_FPS:27.4
#
#  cvWriteFrame
# Objects:
#
# truck: 85%
# car: 46%
# truck: 38%
# car: 28%
# car: 100%
# car: 92%
# car: 74%
# car: 62%
# car: 45%
# car: 32%
# car: 27%
#
# FPS:28.5 	 AVG_FPS:27.4
#
#  cvWriteFrame
# Objects:
#
# truck: 81%
# car: 37%
# truck: 59%
# car: 99%
# car: 89%
# car: 62%
# car: 53%
# car: 51%
# car: 39%
#
# FPS:28.4 	 AVG_FPS:27.4
#
#  cvWriteFrame
# Objects:
#
# truck: 84%
# truck: 67%
# car: 100%
# car: 93%
# car: 73%
# car: 48%
# car: 40%
# car: 36%
#
# FPS:28.2 	 AVG_FPS:27.4
#
#  cvWriteFrame
# Objects:
#
# truck: 43%
# truck: 42%
# car: 76%
# car: 100%
# car: 91%
# car: 68%
# car: 51%
# car: 40%
# car: 39%
# car: 33%
#
# FPS:28.1 	 AVG_FPS:27.4
# ...

# %%
download('/content/results.avi')
